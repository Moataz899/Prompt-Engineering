# %% [markdown]
# # Iterative Prompt Development
# In this lesson, you'll iteratively analyze and refine your prompts to generate marketing copy from a product fact sheet.
#
# ## Setup

# %%
import google.generativeai as genai
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())  # read local .env file

# Load API key from environment variable (recommended)
genai.configure(api_key=os.getenv('GEMINI_API_KEY'))

# %%
def get_completion(prompt, model="gemini-2.5-flash"):
    """Get completion from Gemini 2.5 Flash"""
    model_obj = genai.GenerativeModel(
        model_name=model,
        generation_config={"temperature": 0}  # low temperature for consistent results
    )
    response = model_obj.generate_content(prompt)
    return response.text

# %% [markdown]
# **Note**: This notebook has been updated to use **Google Gemini 2.5 Flash** (free tier) instead of GPT.
#
# Install the required packages:
# ```bash
# pip install -U google-generativeai python-dotenv
# ```

# %% [markdown]
# ## Generate a marketing product description from a product fact sheet

# %%
fact_sheet_chair = """
OVERVIEW
- Part of a beautiful family of mid-century inspired office furniture, 
including filing cabinets, desks, bookcases, meeting tables, and more.
- Several options of shell color and base finishes.
- Available with plastic back and front upholstery (SWC-100) 
or full upholstery (SWC-110) in 10 fabric and 6 leather options.
- Base finish options are: stainless steel, matte black, 
gloss white, or chrome.
- Chair is available with or without armrests.
- Suitable for home or business settings.
- Qualified for contract use.

CONSTRUCTION
- 5-wheel plastic coated aluminum base.
- Pneumatic chair adjust for easy raise/lower action.

DIMENSIONS
- WIDTH 53 CM | 20.87"
- DEPTH 51 CM | 20.08"
- HEIGHT 80 CM | 31.50"
- SEAT HEIGHT 44 CM | 17.32"
- SEAT DEPTH 41 CM | 16.14"

OPTIONS
- Soft or hard-floor caster options.
- Two choices of seat foam densities: 
 medium (1.8 lb/ft3) or high (2.8 lb/ft3)
- Armless or 8 position PU armrests 

MATERIALS
SHELL BASE GLIDER
- Cast Aluminum with modified nylon PA6/PA66 coating.
- Shell thickness: 10 mm.
SEAT
- HD36 foam

COUNTRY OF ORIGIN
- Italy
"""

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# **Elevate Your Space with Timeless Mid-Century Design**
#
# Discover the perfect blend of iconic style and modern functionality with our exquisite office chair, a distinguished member of our beautiful mid-century inspired furniture collection. Designed to seamlessly integrate into any environment, this chair brings sophistication and comfort to both home offices and professional settings.
#
# **Tailored to Your Unique Style**
# Personalize your chair to perfection. Choose from a diverse palette of shell colors and select your preferred base finish: sleek stainless steel, contemporary matte black, crisp gloss white, or classic chrome. Further customize your comfort and aesthetic with either a sophisticated plastic-back upholstery (SWC-100) or luxurious full upholstery (SWC-110), available in 10 premium fabric options and 6 exquisite leathers. Opt for an elegant armless design or enhance your support with 8-position adjustable PU armrests.
#
# **Engineered for Superior Comfort & Durability**
# Experience lasting comfort with your choice of medium or high-density seat foam, ensuring optimal support throughout your day. The robust 10mm thick cast aluminum shell, protected by a modified nylon coating, guarantees exceptional durability. Enjoy effortless mobility with a smooth-gliding 5-wheel plastic-coated aluminum base, available with casters optimized for either soft or hard floors. A pneumatic lift allows for easy and precise height adjustment, adapting to your needs.
#
# **Versatile & Contract-Grade Quality**
# Thoughtfully designed for versatility, this chair is not only an ideal addition to your home office but is also qualified for rigorous contract use in commercial environments. Its considered dimensions (Width: 53 cm | 20.87", Depth: 51 cm | 20.08", Height: 80 cm | 31.50") ensure a comfortable and space-efficient profile. Seat Height: 44 cm | 17.32", Seat Depth: 41 cm | 16.14".
#
# **Proudly Crafted in Italy**
# Embodying a legacy of exceptional design and quality, this chair is proudly crafted in Italy, promising enduring style and superior performance.

# %% [markdown]
# ## Issue 1: The text is too long
# - Limit the number of words/sentences/characters.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Discover our Italian-made, mid-century inspired office chair. Customizable with options for shell color, base finish, upholstery (fabric/leather), and armrests. Perfect for home or business settings, it features pneumatic height adjust and a 5-wheel base. Part of a beautiful furniture family, it blends style and versatility.

# %%
len(response.split())
# Out:
# 45

# %% [markdown]
# ## Issue 2. Text focuses on the wrong details
# - Ask it to focus on the aspects that are relevant to the intended audience.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Constructed with a 10mm thick cast aluminum shell featuring a modified nylon PA6/PA66 coating. It boasts a 5-wheel plastic-coated aluminum base, available in stainless steel, matte black, gloss white, or chrome finishes. Seat options include HD36 foam and various upholstery choices (SWC-100/SWC-110).

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Crafted with a 10mm thick cast aluminum shell, coated in modified nylon PA6/PA66, this chair features a 5-wheel plastic-coated aluminum base. The seat utilizes HD36 foam, available with plastic (SWC-100) or full upholstery (SWC-110). Base finishes include stainless steel, matte black, gloss white, or chrome.
#
# Product IDs: SWC-100, SWC-110

# %% [markdown]
# ## Issue 3. Description needs a table of dimensions
# - Ask it to extract information and organize it in a table.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

After the description, include a table that gives the 
product's dimensions. The table should have two columns.
In the first column include the name of the dimension. 
In the second column include the measurements in inches only.

Give the table the title 'Product Dimensions'.

Format everything as HTML that can be used in a website. 
Place the description in a <div> element.

Technical specifications: ```{fact_sheet_chair}```
"""

response = get_completion(prompt)
print(response)
# Out:
# ```html
# <div>
#     <p>
#         Introducing a versatile office chair designed for both home and business settings, qualified for contract use. This chair is part of a comprehensive family of mid-century inspired office furniture, offering a cohesive aesthetic for any professional environment.
#     </p>
#     <p>
#         The chair's robust construction features a 5-wheel plastic-coated aluminum base, ensuring stability and ease of movement. A pneumatic chair adjust mechanism allows for effortless raise and lower action, adapting to various user preferences and desk heights.
#     </p>
#     <p>
#         Material specifications highlight durability and customization. The shell base glider is crafted from cast aluminum with a modified nylon PA6/PA66 coating, providing a resilient finish. The shell itself boasts a substantial thickness of 10 mm. For seating comfort, the chair utilizes HD36 foam.
#     </p>
#     <p>
#         Retailers can offer a range of customization options to meet diverse client needs. The chair is available with a plastic back and front upholstery (SWC-100) or as a fully upholstered model (SWC-110), with a choice of 10 fabric and 6 leather options. Base finishes include stainless steel, matte black, gloss white, or chrome. Further options include soft or hard-floor casters, two seat foam densities (medium at 1.8 lb/ft3 or high at 2.8 lb/ft3), and the choice of an armless design or 8-position PU armrests.
#     </p>
#     <p>
#         Proudly manufactured in Italy, this chair combines sophisticated design with high-quality materials and construction.
#     </p>
#     <p>Product IDs: SWC-100, SWC-110</p>
# </div>
#
# <h3>Product Dimensions</h3>
# <table border="1">
#     <thead>
#         <tr>
#             <th>Dimension Name</th>
#             <th>Measurements (inches)</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Width</td>
#             <td>20.87"</td>
#         </tr>
#         <tr>
#             <td>Depth</td>
#             <td>20.08"</td>
#         </tr>
#         <tr>
#             <td>Height</td>
#             <td>31.50"</td>
#         </tr>
#         <tr>
#             <td>Seat Height</td>
#             <td>17.32"</td>
#         </tr>
#         <tr>
#             <td>Seat Depth</td>
#             <td>16.14"</td>
#         </tr>
#     </tbody>
# </table>
# ```

# %% [markdown]
# ## Load Python libraries to view HTML

# %%
from IPython.display import display, HTML

# %%
display(HTML(response))
# Out:
# ```html
# <div>
#     <p>
#         Introducing a versatile office chair designed for both home and business settings, qualified for contract use. This chair is part of a comprehensive family of mid-century inspired office furniture, offering a cohesive aesthetic for any professional environment.
#     </p>
#     <p>
#         The chair's robust construction features a 5-wheel plastic-coated aluminum base, ensuring stability and ease of movement. A pneumatic chair adjust mechanism allows for effortless raise and lower action, adapting to various user preferences and desk heights.
#     </p>
#     <p>
#         Material specifications highlight durability and customization. The shell base glider is crafted from cast aluminum with a modified nylon PA6/PA66 coating, providing a resilient finish. The shell itself boasts a substantial thickness of 10 mm. For seating comfort, the chair utilizes HD36 foam.
#     </p>
#     <p>
#         Retailers can offer a range of customization options to meet diverse client needs. The chair is available with a plastic back and front upholstery (SWC-100) or as a fully upholstered model (SWC-110), with a choice of 10 fabric and 6 leather options. Base finishes include stainless steel, matte black, gloss white, or chrome. Further options include soft or hard-floor casters, two seat foam densities (medium at 1.8 lb/ft3 or high at 2.8 lb/ft3), and the choice of an armless design or 8-position PU armrests.
#     </p>
#     <p>
#         Proudly manufactured in Italy, this chair combines sophisticated design with high-quality materials and construction.
#     </p>
#     <p>Product IDs: SWC-100, SWC-110</p>
# </div>
#
# <h3>Product Dimensions</h3>
# <table border="1">
#     <thead>
#         <tr>
#             <th>Dimension Name</th>
#             <th>Measurements (inches)</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Width</td>
#             <td>20.87"</td>
#         </tr>
#         <tr>
#             <td>Depth</td>
#             <td>20.08"</td>
#         </tr>
#         <tr>
#             <td>Height</td>
#             <td>31.50"</td>
#         </tr>
#         <tr>
#             <td>Seat Height</td>
#             <td>17.32"</td>
#         </tr>
#         <tr>
#             <td>Seat Depth</td>
#             <td>16.14"</td>
#         </tr>
#     </tbody>
# </table>
# ```
